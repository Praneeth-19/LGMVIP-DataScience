# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,accuracy_score
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB
import xgboost as xgb
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
import os
for dirname, _, filenames in os.walk('C:\\Users\\prane\\OneDrive\\Desktop\\Data Science\\Lets Grow More\\Music Recommendation\\music recomdation'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:\Users\prane\OneDrive\Desktop\Data Science\Lets Grow More\Music Recommendation\music recomdation\members.csv
# C:\Users\prane\OneDrive\Desktop\Data Science\Lets Grow More\Music Recommendation\music recomdation\songs.csv
# C:\Users\prane\OneDrive\Desktop\Data Science\Lets Grow More\Music Recommendation\music recomdation\song_extra_info.csv
# C:\Users\prane\OneDrive\Desktop\Data Science\Lets Grow More\Music Recommendation\music recomdation\submission.csv
# C:\Users\prane\OneDrive\Desktop\Data Science\Lets Grow More\Music Recommendation\music recomdation\test.csv
# C:\Users\prane\OneDrive\Desktop\Data Science\Lets Grow More\Music Recommendation\music recomdation\train.csv
# C:\Users\prane\OneDrive\Desktop\Data Science\Lets Grow More\Music Recommendation\music recomdation\Untitled.ipynb
# C:\Users\prane\OneDrive\Desktop\Data Science\Lets Grow More\Music Recommendation\music recomdation\.ipynb_checkpoints\Untitled-checkpoint.ipynb

# %%
def reduce_mem_usage(df):
   
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
# !pip install datatable
# Out:
# Collecting datatable
#   Obtaining dependency information for datatable from https://files.pythonhosted.org/packages/bb/c5/987fcb116df777d2573c8918b7d7bb391405fa0ca3ed209238bf447b7aac/datatable-1.1.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading datatable-1.1.0-cp311-cp311-win_amd64.whl.metadata (1.8 kB)
# Downloading datatable-1.1.0-cp311-cp311-win_amd64.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#     --------------------------------------- 0.1/4.7 MB 825.8 kB/s eta 0:00:06
#     --------------------------------------- 0.1/4.7 MB 1.1 MB/s eta 0:00:05
#    -- ------------------------------------- 0.2/4.7 MB 1.5 MB/s eta 0:00:03
#    -- ------------------------------------- 0.3/4.7 MB 1.4 MB/s eta 0:00:04
#    --- ------------------------------------ 0.4/4.7 MB 1.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.5/4.7 MB 1.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.6/4.7 MB 1.6 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.7/4.7 MB 1.8 MB/s eta 0:00:03
#    ------ --------------------------------- 0.8/4.7 MB 1.9 MB/s eta 0:00:03
#    ------- -------------------------------- 0.9/4.7 MB 1.9 MB/s eta 0:00:02
#    -------- ------------------------------- 1.0/4.7 MB 1.9 MB/s eta 0:00:02
#    --------- ------------------------------ 1.1/4.7 MB 1.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.2/4.7 MB 2.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.2/4.7 MB 2.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.2/4.7 MB 2.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.2/4.7 MB 2.0 MB/s eta 0:00:02
#    ------------ --------------------------- 1.5/4.7 MB 1.8 MB/s eta 0:00:02
#    ------------ --------------------------- 1.5/4.7 MB 1.7 MB/s eta 0:00:02
#    ------------- -------------------------- 1.6/4.7 MB 1.8 MB/s eta 0:00:02
#    --------------- ------------------------ 1.8/4.7 MB 1.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.9/4.7 MB 1.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 2.1/4.7 MB 2.0 MB/s eta 0:00:02
#    ------------------- -------------------- 2.2/4.7 MB 2.1 MB/s eta 0:00:02
#    -------------------- ------------------- 2.4/4.7 MB 2.1 MB/s eta 0:00:02
#    --------------------- ------------------ 2.5/4.7 MB 2.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 2.7/4.7 MB 2.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.8/4.7 MB 2.3 MB/s eta 0:00:01
#    ------------------------ --------------- 2.9/4.7 MB 2.2 MB/s eta 0:00:01
#    ------------------------- -------------- 3.1/4.7 MB 2.2 MB/s eta 0:00:01
#    -------------------------- ------------- 3.1/4.7 MB 2.3 MB/s eta 0:00:01
#    -------------------------- ------------- 3.1/4.7 MB 2.3 MB/s eta 0:00:01
#    --------------------------- ------------ 3.2/4.7 MB 2.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.4/4.7 MB 2.2 MB/s eta 0:00:01
#    ------------------------------ --------- 3.5/4.7 MB 2.2 MB/s eta 0:00:01
#    ------------------------------ --------- 3.7/4.7 MB 2.2 MB/s eta 0:00:01
#    -------------------------------- ------- 3.8/4.7 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 4.0/4.7 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.1/4.7 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.2/4.7 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.2/4.7 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.2/4.7 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------ --- 4.3/4.7 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 4.4/4.7 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 4.4/4.7 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 4.4/4.7 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  4.7/4.7 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 2.2 MB/s eta 0:00:00
# Installing collected packages: datatable
# Successfully installed datatable-1.1.0
# DEPRECATION: google-images-search 1.4.6 has a non-standard dependency specifier click>=7.0<=8.1.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of google-images-search or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# WARNING: There was an error checking the latest version of pip.

# %%
train_data = pd.read_csv(r"C:\\Users\\prane\\OneDrive\\Desktop\\Data Science\\Lets Grow More\\Music Recommendation\\music recomdation\\train.csv")

# %%
train_data.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target
# 0              Explore  online-playlist       1
# 1  Local playlist more   local-playlist       1
# 2  Local playlist more   local-playlist       1
# 3  Local playlist more   local-playlist       1
# 4              Explore  online-playlist       1

# %%
songs_data = pd.read_csv(r"C:\\Users\\prane\\OneDrive\\Desktop\\Data Science\\Lets Grow More\\Music Recommendation\\music recomdation\\songs.csv")
songs_data.head()
# Out:
#                                         song_id  song_length genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 1  o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328       444
# 2  DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781       465
# 3  dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554       465
# 4  W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329       726
#
#         artist_name                            composer     lyricist  language
# 0  張信哲 (Jeff Chang)                                  董貞          何啟弘       3.0
# 1         BLACKPINK  TEDDY|  FUTURE BOUNCE|  Bekuh BOOM        TEDDY      31.0
# 2      SUPER JUNIOR                                 NaN          NaN      31.0
# 3             S.H.E                                 湯小康          徐世珍       3.0
# 4              貴族精選                         Traditional  Traditional      52.0

# %%
members_data = pd.read_csv(r"C:\\Users\\prane\\OneDrive\\Desktop\\Data Science\\Lets Grow More\\Music Recommendation\\music recomdation\\members.csv")
members_data.head()
# Out:
#                                            msno  city  bd gender  \
# 0  XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=     1   0    NaN
# 1  UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=     1   0    NaN
# 2  D8nEhsIOBSoE6VthTaqDX8U6lqjJ7dLdr72mOyLya2A=     1   0    NaN
# 3  mCuD+tZ1hERA/o5GPqk38e041J8ZsBaLcu7nGoIIvhI=     1   0    NaN
# 4  q4HRBfVSssAFS9iRfxWrohxuk9kCYMKjHOEagUMV6rQ=     1   0    NaN
#
#    registered_via  registration_init_time  expiration_date
# 0               7                20110820         20170920
# 1               7                20150628         20170622
# 2               4                20160411         20170712
# 3               9                20150906         20150907
# 4               4                20170126         20170613

# %%
songs_data = pd.read_csv(r"C:\\Users\\prane\\OneDrive\\Desktop\\Data Science\\Lets Grow More\\Music Recommendation\\music recomdation\\songs.csv")
songs_data.head()
# Out:
#                                         song_id  song_length genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 1  o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328       444
# 2  DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781       465
# 3  dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554       465
# 4  W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329       726
#
#         artist_name                            composer     lyricist  language
# 0  張信哲 (Jeff Chang)                                  董貞          何啟弘       3.0
# 1         BLACKPINK  TEDDY|  FUTURE BOUNCE|  Bekuh BOOM        TEDDY      31.0
# 2      SUPER JUNIOR                                 NaN          NaN      31.0
# 3             S.H.E                                 湯小康          徐世珍       3.0
# 4              貴族精選                         Traditional  Traditional      52.0

# %%
#C:\\Users\\prane\\OneDrive\\Desktop\\Data Science\\Lets Grow More\\Music Recommendation\\music recomdation\\

# %%
train_df = pd.merge(train_data, songs_data, on='song_id', how='left')
del songs_data

train_df = pd.merge(train_data, members_data, on='msno', how='left')
del members_data

# %%
train_df.shape
# Out:
# (7377418, 12)

# %%
train_df.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target  city  bd  gender  \
# 0              Explore  online-playlist       1     1   0     NaN
# 1  Local playlist more   local-playlist       1    13  24  female
# 2  Local playlist more   local-playlist       1    13  24  female
# 3  Local playlist more   local-playlist       1    13  24  female
# 4              Explore  online-playlist       1     1   0     NaN
#
#    registered_via  registration_init_time  expiration_date
# 0               7                20120102         20171005
# 1               9                20110525         20170911
# 2               9                20110525         20170911
# 3               9                20110525         20170911
# 4               7                20120102         20171005

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7377418 entries, 0 to 7377417
# Data columns (total 12 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   msno                    object
#  1   song_id                 object
#  2   source_system_tab       object
#  3   source_screen_name      object
#  4   source_type             object
#  5   target                  int64
#  6   city                    int64
#  7   bd                      int64
#  8   gender                  object
#  9   registered_via          int64
#  10  registration_init_time  int64
#  11  expiration_date         int64
# dtypes: int64(6), object(6)
# memory usage: 675.4+ MB

# %%
def find_dirty_values(data):
    dtypes = pd.DataFrame(data.dtypes,columns=["Data Type"])
    dtypes["Unique Values"]=data.nunique().sort_values(ascending=True)
    dtypes["Null Values"]=data.isnull().sum()
    dtypes["% null Values"]=data.isnull().sum()/len(data)
    return dtypes.sort_values(by="Null Values" , ascending=False).style.background_gradient(cmap='YlOrRd',axis=0)

# %%
result = find_dirty_values(train_df)
result
# Out:
# <style type="text/css">
# #T_0f333_row0_col1, #T_0f333_row1_col1, #T_0f333_row2_col1, #T_0f333_row3_col1, #T_0f333_row4_col2, #T_0f333_row4_col3, #T_0f333_row5_col2, #T_0f333_row5_col3, #T_0f333_row6_col1, #T_0f333_row6_col2, #T_0f333_row6_col3, #T_0f333_row7_col1, #T_0f333_row7_col2, #T_0f333_row7_col3, #T_0f333_row8_col1, #T_0f333_row8_col2, #T_0f333_row8_col3, #T_0f333_row9_col1, #T_0f333_row9_col2, #T_0f333_row9_col3, #T_0f333_row10_col2, #T_0f333_row10_col3, #T_0f333_row11_col1, #T_0f333_row11_col2, #T_0f333_row11_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_0f333_row0_col2, #T_0f333_row0_col3, #T_0f333_row5_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_0f333_row1_col2, #T_0f333_row1_col3 {
#   background-color: #ffeb9c;
#   color: #000000;
# }
# #T_0f333_row2_col2, #T_0f333_row2_col3, #T_0f333_row10_col1 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_0f333_row3_col2, #T_0f333_row3_col3 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_0f333_row4_col1 {
#   background-color: #fff3af;
#   color: #000000;
# }
# </style>
# <table id="T_0f333">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f333_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_0f333_level0_col1" class="col_heading level0 col1" >Unique Values</th>
#       <th id="T_0f333_level0_col2" class="col_heading level0 col2" >Null Values</th>
#       <th id="T_0f333_level0_col3" class="col_heading level0 col3" >% null Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f333_level0_row0" class="row_heading level0 row0" >gender</th>
#       <td id="T_0f333_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_0f333_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_0f333_row0_col2" class="data row0 col2" >2961479</td>
#       <td id="T_0f333_row0_col3" class="data row0 col3" >0.401425</td>
#     </tr>
#     <tr>
#       <th id="T_0f333_level0_row1" class="row_heading level0 row1" >source_screen_name</th>
#       <td id="T_0f333_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_0f333_row1_col1" class="data row1 col1" >20</td>
#       <td id="T_0f333_row1_col2" class="data row1 col2" >414804</td>
#       <td id="T_0f333_row1_col3" class="data row1 col3" >0.056226</td>
#     </tr>
#     <tr>
#       <th id="T_0f333_level0_row2" class="row_heading level0 row2" >source_system_tab</th>
#       <td id="T_0f333_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_0f333_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_0f333_row2_col2" class="data row2 col2" >24849</td>
#       <td id="T_0f333_row2_col3" class="data row2 col3" >0.003368</td>
#     </tr>
#     <tr>
#       <th id="T_0f333_level0_row3" class="row_heading level0 row3" >source_type</th>
#       <td id="T_0f333_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_0f333_row3_col1" class="data row3 col1" >12</td>
#       <td id="T_0f333_row3_col2" class="data row3 col2" >21539</td>
#       <td id="T_0f333_row3_col3" class="data row3 col3" >0.002920</td>
#     </tr>
#     <tr>
#       <th id="T_0f333_level0_row4" class="row_heading level0 row4" >msno</th>
#       <td id="T_0f333_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_0f333_row4_col1" class="data row4 col1" >30755</td>
#       <td id="T_0f333_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_0f333_row4_col3" class="data row4 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0f333_level0_row5" class="row_heading level0 row5" >song_id</th>
#       <td id="T_0f333_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_0f333_row5_col1" class="data row5 col1" >359966</td>
#       <td id="T_0f333_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_0f333_row5_col3" class="data row5 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0f333_level0_row6" class="row_heading level0 row6" >target</th>
#       <td id="T_0f333_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_0f333_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_0f333_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_0f333_row6_col3" class="data row6 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0f333_level0_row7" class="row_heading level0 row7" >city</th>
#       <td id="T_0f333_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_0f333_row7_col1" class="data row7 col1" >21</td>
#       <td id="T_0f333_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_0f333_row7_col3" class="data row7 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0f333_level0_row8" class="row_heading level0 row8" >bd</th>
#       <td id="T_0f333_row8_col0" class="data row8 col0" >int64</td>
#       <td id="T_0f333_row8_col1" class="data row8 col1" >92</td>
#       <td id="T_0f333_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_0f333_row8_col3" class="data row8 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0f333_level0_row9" class="row_heading level0 row9" >registered_via</th>
#       <td id="T_0f333_row9_col0" class="data row9 col0" >int64</td>
#       <td id="T_0f333_row9_col1" class="data row9 col1" >5</td>
#       <td id="T_0f333_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_0f333_row9_col3" class="data row9 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0f333_level0_row10" class="row_heading level0 row10" >registration_init_time</th>
#       <td id="T_0f333_row10_col0" class="data row10 col0" >int64</td>
#       <td id="T_0f333_row10_col1" class="data row10 col1" >3811</td>
#       <td id="T_0f333_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_0f333_row10_col3" class="data row10 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0f333_level0_row11" class="row_heading level0 row11" >expiration_date</th>
#       <td id="T_0f333_row11_col0" class="data row11 col0" >int64</td>
#       <td id="T_0f333_row11_col1" class="data row11 col1" >1395</td>
#       <td id="T_0f333_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_0f333_row11_col3" class="data row11 col3" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
def handling_missing_values(dataframe):
    cat_cols = dataframe.select_dtypes(include='O').columns
    num_cols = dataframe.select_dtypes(include=(np.number)).columns
    for col in cat_cols:
        dataframe[col] = dataframe[col].fillna('UnKnown')
    for col in num_cols:
        dataframe[col] = dataframe[col].interpolate(method='linear')
    return dataframe

# %%
train_df = handling_missing_values(train_df)
result = find_dirty_values(train_df)
result
# Out:
# <style type="text/css">
# #T_18d2f_row0_col1 {
#   background-color: #fff3af;
#   color: #000000;
# }
# #T_18d2f_row0_col2, #T_18d2f_row0_col3, #T_18d2f_row1_col2, #T_18d2f_row1_col3, #T_18d2f_row2_col1, #T_18d2f_row2_col2, #T_18d2f_row2_col3, #T_18d2f_row3_col1, #T_18d2f_row3_col2, #T_18d2f_row3_col3, #T_18d2f_row4_col1, #T_18d2f_row4_col2, #T_18d2f_row4_col3, #T_18d2f_row5_col1, #T_18d2f_row5_col2, #T_18d2f_row5_col3, #T_18d2f_row6_col1, #T_18d2f_row6_col2, #T_18d2f_row6_col3, #T_18d2f_row7_col1, #T_18d2f_row7_col2, #T_18d2f_row7_col3, #T_18d2f_row8_col1, #T_18d2f_row8_col2, #T_18d2f_row8_col3, #T_18d2f_row9_col1, #T_18d2f_row9_col2, #T_18d2f_row9_col3, #T_18d2f_row10_col2, #T_18d2f_row10_col3, #T_18d2f_row11_col1, #T_18d2f_row11_col2, #T_18d2f_row11_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_18d2f_row1_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_18d2f_row10_col1 {
#   background-color: #fffec9;
#   color: #000000;
# }
# </style>
# <table id="T_18d2f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18d2f_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_18d2f_level0_col1" class="col_heading level0 col1" >Unique Values</th>
#       <th id="T_18d2f_level0_col2" class="col_heading level0 col2" >Null Values</th>
#       <th id="T_18d2f_level0_col3" class="col_heading level0 col3" >% null Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18d2f_level0_row0" class="row_heading level0 row0" >msno</th>
#       <td id="T_18d2f_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_18d2f_row0_col1" class="data row0 col1" >30755</td>
#       <td id="T_18d2f_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_18d2f_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18d2f_level0_row1" class="row_heading level0 row1" >song_id</th>
#       <td id="T_18d2f_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_18d2f_row1_col1" class="data row1 col1" >359966</td>
#       <td id="T_18d2f_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_18d2f_row1_col3" class="data row1 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18d2f_level0_row2" class="row_heading level0 row2" >source_system_tab</th>
#       <td id="T_18d2f_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_18d2f_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_18d2f_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_18d2f_row2_col3" class="data row2 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18d2f_level0_row3" class="row_heading level0 row3" >source_screen_name</th>
#       <td id="T_18d2f_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_18d2f_row3_col1" class="data row3 col1" >21</td>
#       <td id="T_18d2f_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_18d2f_row3_col3" class="data row3 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18d2f_level0_row4" class="row_heading level0 row4" >source_type</th>
#       <td id="T_18d2f_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_18d2f_row4_col1" class="data row4 col1" >13</td>
#       <td id="T_18d2f_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_18d2f_row4_col3" class="data row4 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18d2f_level0_row5" class="row_heading level0 row5" >target</th>
#       <td id="T_18d2f_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_18d2f_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_18d2f_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_18d2f_row5_col3" class="data row5 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18d2f_level0_row6" class="row_heading level0 row6" >city</th>
#       <td id="T_18d2f_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_18d2f_row6_col1" class="data row6 col1" >21</td>
#       <td id="T_18d2f_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_18d2f_row6_col3" class="data row6 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18d2f_level0_row7" class="row_heading level0 row7" >bd</th>
#       <td id="T_18d2f_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_18d2f_row7_col1" class="data row7 col1" >92</td>
#       <td id="T_18d2f_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_18d2f_row7_col3" class="data row7 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18d2f_level0_row8" class="row_heading level0 row8" >gender</th>
#       <td id="T_18d2f_row8_col0" class="data row8 col0" >object</td>
#       <td id="T_18d2f_row8_col1" class="data row8 col1" >3</td>
#       <td id="T_18d2f_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_18d2f_row8_col3" class="data row8 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18d2f_level0_row9" class="row_heading level0 row9" >registered_via</th>
#       <td id="T_18d2f_row9_col0" class="data row9 col0" >int64</td>
#       <td id="T_18d2f_row9_col1" class="data row9 col1" >5</td>
#       <td id="T_18d2f_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_18d2f_row9_col3" class="data row9 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18d2f_level0_row10" class="row_heading level0 row10" >registration_init_time</th>
#       <td id="T_18d2f_row10_col0" class="data row10 col0" >int64</td>
#       <td id="T_18d2f_row10_col1" class="data row10 col1" >3811</td>
#       <td id="T_18d2f_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_18d2f_row10_col3" class="data row10 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18d2f_level0_row11" class="row_heading level0 row11" >expiration_date</th>
#       <td id="T_18d2f_row11_col0" class="data row11 col0" >int64</td>
#       <td id="T_18d2f_row11_col1" class="data row11 col1" >1395</td>
#       <td id="T_18d2f_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_18d2f_row11_col3" class="data row11 col3" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
date_cols = ['registration_init_time','expiration_date']
def date_formatting(date):
    date = str(date)
    date = f"{date[:4]}-{date[4:6]}-{date[6:]}"
    return date
def paring_date(dataframe,date):
    dataframe[date] = pd.to_datetime(dataframe[date])
    dataframe[f"{date}-day"] = dataframe[date].dt.day
    dataframe[f"{date}-month"] = dataframe[date].dt.month
    dataframe[f"{date}-year"] = dataframe[date].dt.year
    return dataframe

# %%
for col in date_cols:
    train_df[col] = train_df[col].apply(date_formatting)
    train_df = paring_date(train_df,col)

# %%
train_df.loc[:,'registration_init_time':].head(10)
# Out:
#   registration_init_time expiration_date  registration_init_time-day  \
# 0             2012-01-02      2017-10-05                           2
# 1             2011-05-25      2017-09-11                          25
# 2             2011-05-25      2017-09-11                          25
# 3             2011-05-25      2017-09-11                          25
# 4             2012-01-02      2017-10-05                           2
# 5             2012-01-02      2017-10-05                           2
# 6             2011-05-25      2017-09-11                          25
# 7             2012-01-02      2017-10-05                           2
# 8             2011-11-07      2018-03-04                           7
# 9             2011-11-07      2018-03-04                           7
#
#    registration_init_time-month  registration_init_time-year  \
# 0                             1                         2012
# 1                             5                         2011
# 2                             5                         2011
# 3                             5                         2011
# 4                             1                         2012
# 5                             1                         2012
# 6                             5                         2011
# 7                             1                         2012
# 8                            11                         2011
# 9                            11                         2011
#
#    expiration_date-day  expiration_date-month  expiration_date-year
# 0                    5                     10                  2017
# 1                   11                      9                  2017
# 2                   11                      9                  2017
# 3                   11                      9                  2017
# 4                    5                     10                  2017
# 5                    5                     10                  2017
# 6                   11                      9                  2017
# 7                    5                     10                  2017
# 8                    4                      3                  2018
# 9                    4                      3                  2018

# %%
train_df.shape
# Out:
# (7377418, 18)

# %%
cat_cols = train_df.select_dtypes(include="O").columns
encoder = LabelEncoder()
for col in cat_cols:
    train_df[col] = encoder.fit_transform(train_df[col])

# %%
x = train_df.drop(columns={"registration_init_time","expiration_date","song_id","msno"})
x.head()
# Out:
#    source_system_tab  source_screen_name  source_type  target  city  bd  \
# 0                  2                   7            7       1     1   0
# 1                  4                   8            5       1    13  24
# 2                  4                   8            5       1    13  24
# 3                  4                   8            5       1    13  24
# 4                  2                   7            7       1     1   0
#
#    gender  registered_via  registration_init_time-day  \
# 0       0               7                           2
# 1       1               9                          25
# 2       1               9                          25
# 3       1               9                          25
# 4       0               7                           2
#
#    registration_init_time-month  registration_init_time-year  \
# 0                             1                         2012
# 1                             5                         2011
# 2                             5                         2011
# 3                             5                         2011
# 4                             1                         2012
#
#    expiration_date-day  expiration_date-month  expiration_date-year
# 0                    5                     10                  2017
# 1                   11                      9                  2017
# 2                   11                      9                  2017
# 3                   11                      9                  2017
# 4                    5                     10                  2017

# %%
x.shape
# Out:
# (7377418, 14)

# %%
y = x.pop('target')

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.3,random_state=42)

# %%
print(f"Shape Of Training Data Set : ",x_train.shape)
print(f"Shape Of Testing Data Set :",x_test.shape)
print(f"Shape Of Train Label :",y_train.shape)
print(f"Shape Of Test Label :",y_test.shape)
# Out:
# Shape Of Training Data Set :  (5164192, 13)
# Shape Of Testing Data Set : (2213226, 13)
# Shape Of Train Label : (5164192,)
# Shape Of Test Label : (2213226,)

# %%
lr = LogisticRegression(max_iter=300,C=0.001,penalty="l2")
lr.fit(x_train,y_train)
train_pred = lr.predict(x_train)
test_pred = lr.predict(x_test)
lr_train_acc = accuracy_score(y_train,train_pred)
lr_test_acc = accuracy_score(y_test,test_pred)
print("Training Accuracy : ",lr_train_acc)
print("Test Accuracy : ",lr_test_acc)
print("Classification Report:\n",classification_report(y_train,train_pred))
# Out:
# Training Accuracy :  0.5989459725742188
# Test Accuracy :  0.5991475791446513
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.55      0.58   2564524
#            1       0.59      0.64      0.62   2599668
#
#     accuracy                           0.60   5164192
#    macro avg       0.60      0.60      0.60   5164192
# weighted avg       0.60      0.60      0.60   5164192

# %%
NB = GaussianNB(var_smoothing=0.01)
NB.fit(x_train,y_train)
train_pred = NB.predict(x_train)
test_pred = NB.predict(x_test)
NB_train_acc = accuracy_score(y_train,train_pred)
NB_test_acc = accuracy_score(y_test,test_pred)
print("Training Accuracy : ",NB_train_acc)
print("Test Accuracy : ",NB_test_acc)
print("Classification Report:\n",classification_report(y_train,train_pred))
# Out:
# Training Accuracy :  0.5583400074977848
# Test Accuracy :  0.5584576541211788
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.29      0.39   2564524
#            1       0.54      0.82      0.65   2599668
#
#     accuracy                           0.56   5164192
#    macro avg       0.58      0.56      0.52   5164192
# weighted avg       0.58      0.56      0.52   5164192

# %%
Dtree = DecisionTreeClassifier(max_depth=None,min_samples_leaf=1,min_samples_split=5)
Dtree.fit(x_train,y_train)
train_pred = Dtree.predict(x_train)
test_pred = Dtree.predict(x_test)
Dtree_train_acc = accuracy_score(y_train,train_pred)
Dtree_test_acc = accuracy_score(y_test,test_pred)
print("Training Accuracy : ",Dtree_train_acc)
print("Test Accuracy : ",Dtree_test_acc)
print("Classification Report:\n",classification_report(y_train,train_pred))
# Out:
# Training Accuracy :  0.7318800307966861
# Test Accuracy :  0.7133564308389654
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.74      0.73   2564524
#            1       0.74      0.72      0.73   2599668
#
#     accuracy                           0.73   5164192
#    macro avg       0.73      0.73      0.73   5164192
# weighted avg       0.73      0.73      0.73   5164192

# %%
gb = GradientBoostingClassifier(learning_rate=.1,max_depth=4,n_estimators=50)
gb.fit(x_train,y_train)
train_pred = gb.predict(x_train)
test_pred = gb.predict(x_test)
gb_train_acc = accuracy_score(y_train,train_pred)
gb_test_acc = accuracy_score(y_test,test_pred)
print("Training Accuracy : ",gb_train_acc)
print("Test Accuracy : ",gb_test_acc)
print("Classification Report:\n",classification_report(y_train,train_pred))
# Out:
# Training Accuracy :  0.6265076898767513
# Test Accuracy :  0.626886725530967
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.66      0.64   2564524
#            1       0.64      0.60      0.62   2599668
#
#     accuracy                           0.63   5164192
#    macro avg       0.63      0.63      0.63   5164192
# weighted avg       0.63      0.63      0.63   5164192

# %%
xg = xgb.XGBClassifier(random_state=0,learning_rate=.01,max_depth=3,n_estimators=50)
xg.fit(x_train,y_train)
train_pred = xg.predict(x_train)
test_pred = xg.predict(x_test)
xg_train_acc = accuracy_score(y_train,train_pred)
xg_test_acc = accuracy_score(y_test,test_pred)
print("Training Accuracy : ",xg_train_acc)
print("Test Accuracy : ",xg_test_acc)
print("Classification Report:\n",classification_report(y_train,train_pred))
# Out:
# Training Accuracy :  0.6236526449829906
# Test Accuracy :  0.6240736373059055
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.67      0.64   2564524
#            1       0.64      0.58      0.61   2599668
#
#     accuracy                           0.62   5164192
#    macro avg       0.63      0.62      0.62   5164192
# weighted avg       0.63      0.62      0.62   5164192

# %%
cols = [
    ["Logistic Regression",lr_train_acc,lr_test_acc],
    ["Naive Bayes",NB_train_acc,NB_test_acc],
    ["Decision Trees",Dtree_train_acc,Dtree_test_acc],
    ["Gradient Boosting",gb_train_acc,gb_test_acc],
    ["XGBoost",xg_train_acc,xg_test_acc]
    ]
results = pd.DataFrame( cols,
                       columns = ["Model","Training Accuracy %","Test Evaluation %"]).sort_values(
                        by="Test Evaluation %",ascending=False)
results.style.background_gradient(cmap='Set1')
# Out:
# <style type="text/css">
# #T_3929a_row0_col1, #T_3929a_row0_col2 {
#   background-color: #999999;
#   color: #f1f1f1;
# }
# #T_3929a_row1_col1, #T_3929a_row1_col2, #T_3929a_row2_col1, #T_3929a_row2_col2 {
#   background-color: #984ea3;
#   color: #f1f1f1;
# }
# #T_3929a_row3_col1, #T_3929a_row3_col2 {
#   background-color: #4daf4a;
#   color: #f1f1f1;
# }
# #T_3929a_row4_col1, #T_3929a_row4_col2 {
#   background-color: #e41a1c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3929a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3929a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3929a_level0_col1" class="col_heading level0 col1" >Training Accuracy %</th>
#       <th id="T_3929a_level0_col2" class="col_heading level0 col2" >Test Evaluation %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3929a_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_3929a_row0_col0" class="data row0 col0" >Decision Trees</td>
#       <td id="T_3929a_row0_col1" class="data row0 col1" >0.731880</td>
#       <td id="T_3929a_row0_col2" class="data row0 col2" >0.713356</td>
#     </tr>
#     <tr>
#       <th id="T_3929a_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_3929a_row1_col0" class="data row1 col0" >Gradient Boosting</td>
#       <td id="T_3929a_row1_col1" class="data row1 col1" >0.626508</td>
#       <td id="T_3929a_row1_col2" class="data row1 col2" >0.626887</td>
#     </tr>
#     <tr>
#       <th id="T_3929a_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_3929a_row2_col0" class="data row2 col0" >XGBoost</td>
#       <td id="T_3929a_row2_col1" class="data row2 col1" >0.623653</td>
#       <td id="T_3929a_row2_col2" class="data row2 col2" >0.624074</td>
#     </tr>
#     <tr>
#       <th id="T_3929a_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_3929a_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_3929a_row3_col1" class="data row3 col1" >0.598946</td>
#       <td id="T_3929a_row3_col2" class="data row3 col2" >0.599148</td>
#     </tr>
#     <tr>
#       <th id="T_3929a_level0_row4" class="row_heading level0 row4" >1</th>
#       <td id="T_3929a_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_3929a_row4_col1" class="data row4 col1" >0.558340</td>
#       <td id="T_3929a_row4_col2" class="data row4 col2" >0.558458</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_df = x_test.reset_index()
test_df.head()
# Out:
#      index  source_system_tab  source_screen_name  source_type  city  bd  \
# 0  1919950                  7                  15            9     1   0
# 1   358522                  1                  19           11    22  21
# 2  5324459                  6                  14            8    14  30
# 3  3353377                  4                   8            5    11  26
# 4  3930239                  1                   1           11    14   0
#
#    gender  registered_via  registration_init_time-day  \
# 0       0               7                          24
# 1       1               3                           2
# 2       1               9                          10
# 3       1               9                          28
# 4       0               9                           8
#
#    registration_init_time-month  registration_init_time-year  \
# 0                             1                         2014
# 1                            11                         2014
# 2                             3                         2006
# 3                             9                         2007
# 4                             3                         2015
#
#    expiration_date-day  expiration_date-month  expiration_date-year
# 0                    6                     10                  2017
# 1                   17                      6                  2017
# 2                   24                      9                  2017
# 3                   30                      9                  2017
# 4                    8                      9                  2017

# %%
predictions = Dtree.predict(pd.DataFrame(x_test).values)
sub = pd.DataFrame()
sub['id'] = test_df['index']
sub['target'] = predictions
sub.to_csv('submission.csv',index=False)
sub.head()
# Out:
#         id  target
# 0  1919950       0
# 1   358522       0
# 2  5324459       0
# 3  3353377       1
# 4  3930239       0
